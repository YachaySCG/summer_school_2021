# %% [markdown]
# # Data Preparation
#
# This is the notebook for data preparation for the challenge SC 2021

# %%
import os
from glob import glob
from PIL import Image
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-11-29e27f66d4f9> in <module>
#       2 from glob import glob
#       3 from PIL import Image
# ----> 4 import numpy as np
#
# ModuleNotFoundError: No module named 'numpy'

# %%
DATA_DIR = "stuff/data/"
DATA_TRAIN = os.path.join(DATA_DIR, "train")
DATA_VAL = os.path.join(DATA_DIR, "test")
DATA_PRED = os.path.join(DATA_DIR, "pred")

# %%
print("Dataset Size ...")

print("Train images:")
# !ls -R $DATA_TRAIN | wc -l

print("Validation images:")
# !ls -R $DATA_VAL | wc -l

print("Prediction images:")
# !ls $DATA_PRED | wc -l
# Out:
# Dataset Size ...
# Train images:
# 14053
# Validation images:
# 3019
# Prediction images:
# 7301

# %%
arr = []

for folder_name in glob(DATA_TRAIN + "/*/"):
    for img_name in glob(folder_name + "/*.jpg"):
        arr.append(Image.open(img_name))
        print(img_name)
        break
# Out:
# stuff/data/train/glacier/5155.jpg
# stuff/data/train/sea/2461.jpg
# stuff/data/train/mountain/7393.jpg
# stuff/data/train/street/7367.jpg
# stuff/data/train/forest/8732.jpg
# stuff/data/train/buildings/14568.jpg

# %%
arr[1]
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=150x150 at 0x7FB77722B950>
